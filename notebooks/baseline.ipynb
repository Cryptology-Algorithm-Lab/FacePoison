# %%
# Run from the repo root so relative imports and `!`-shell commands resolve.
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

# %% [markdown]
# # Train clean FR baselines
#
# Each command trains one backbone on the clean dataset (no poison applied).
# Swap the config path and the run name as needed; see `configs/` for available
# combinations.

# %%
# Example: train ResNet-50 on CASIA-WebFace.
# Available configs:
#   configs/casia_{r18,mbf,r50,r100,vitb}
#   configs/ms1mv3_{r18,r50,r100,vitb}
#   configs/ms1mv3_r50_onegpu       (single-GPU variant)
# !torchrun --nnodes 1 --nproc-per-node 4 train.py configs/casia_r50 CASIA_R50
