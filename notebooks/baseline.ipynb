# %%
# Run from the repo root so relative imports and `!`-shell commands resolve.
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

# %%
# !torchrun --nnodes 1 --nproc-per-node 4 train.py configs/casia_r18 CASIA_R18

# %%
# !torchrun --nnodes 1 --nproc-per-node 4 train.py configs/casia_mbf CASIA_MBF

# %%
# !torchrun --nnodes 1 --nproc-per-node 4 train.py configs/casia_r50 CASIA_R50

# %%
# !torchrun --nnodes 1 --nproc-per-node 4 train.py configs/casia_r100 CASIA_R100

# %%
# !torchrun --nnodes 1 --nproc-per-node 4 train.py configs/casia_vitb CASIA_VITB

# %%
# !torchrun --nnodes 1 --nproc-per-node 4 train.py configs/ms1mv3_vitb MS1MV3_VITB
